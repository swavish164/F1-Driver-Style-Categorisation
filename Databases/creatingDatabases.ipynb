# %%
import sqlite3
predictionDatabase = sqlite3.connect('database.db')
cursor = predictionDatabase.cursor()
cursor.execute("PRAGMA foreign_keys = ON;")

# %%
cursor.executescript("""
CREATE TABLE Race (
    raceId INTEGER PRIMARY KEY AUTOINCREMENT,
    year INTEGER,
    circuit TEXT
);

CREATE TABLE Driver (
    driverId INTEGER PRIMARY KEY AUTOINCREMENT,
    code TEXT UNIQUE NOT NULL,
    raceId INTEGER,
    name TEXT,
    team TEXT,
    FOREIGN KEY (raceId) REFERENCES Race(raceId)
);

CREATE TABLE Lap (
    lapId INTEGER PRIMARY KEY AUTOINCREMENT,
    raceId INTEGER,
    driverId INTEGER,
    lapNumber INTEGER,
    attacking INTEGER,
    defending INTEGER,
    clean INTEGER,
    FOREIGN KEY (raceId) REFERENCES Race(raceId)
    FOREIGN KEY (driverId) REFERENCES Driver(driverId)
);

CREATE TABLE Features (
    lapId INTEGER PRIMARY KEY,
    throttlePerc100 REAL,
    throttlePerc0 REAL,
    avCornerBrakeDistance REAL,
    throttleOscillation REAL,
    coastingPerc REAL,
    FOREIGN KEY (lapId) REFERENCES Lap(lapId)
);
""")

predictionDatabase.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cursor.executescript("""
#       2 CREATE TABLE Race (
#       3     raceId INTEGER PRIMARY KEY AUTOINCREMENT,
#       4     year INTEGER,
#       5     circuit TEXT
#       6 );
#       7
#       8 CREATE TABLE Driver (
#       9     driverId INTEGER PRIMARY KEY AUTOINCREMENT,
#      10     code TEXT UNIQUE NOT NULL,
#      11     raceId INTEGER,
#      12     name TEXT,
#      13     team TEXT,
#      14     FOREIGN KEY (raceId) REFERENCES Race(raceId)
#      15 );
#      16
#      17 CREATE TABLE Lap (
#      18     lapId INTEGER PRIMARY KEY AUTOINCREMENT,
#      19     raceId INTEGER,
#      20     driverId INTEGER,
#      21     lapNumber INTEGER,
#      22     attacking INTEGER,
#      23     defending INTEGER,
#      24     clean INTEGER,
#      25     FOREIGN KEY (raceId) REFERENCES Race(raceId)
#      26     FOREIGN KEY (driverId) REFERENCES Driver(driverId)
#      27 );
#      28
#      29 CREATE TABLE Features (
#      30     lapId INTEGER PRIMARY KEY,
#      31     throttlePerc100 REAL,
#      32     throttlePerc0 REAL,
#      33     avCornerBrakeDistance REAL,
#      34     throttleOscillation REAL,
#      35     coastingPerc REAL,
#      36     FOREIGN KEY (lapId) REFERENCES Lap(lapId)
#      37 );
#      38 """)
#      40 predictionDatabase.commit()
#
# OperationalError: table Race already exists

# %%
#cursor = predictionDatabase.cursor()
cursor.execute("SELECT * FROM 'Features' LIMIT 210,30")
tables = cursor.fetchall()

print(tables)
cursor.close()
# Out:
# []
