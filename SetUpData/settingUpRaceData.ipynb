# %%
import sys
sys.path.append(r'C:\\Users\\swavi\\Documents\\GitHub\\F1-Stop-Strategy')
from SetUpData.loadSession import getSession
from SetUpData.settingUpData import calculatingDriverLaps

import fastf1
year = 2025
races = fastf1.get_event_schedule(2025,include_testing=False)
racesInYear = races.shape[0]
for i in range(1,racesInYear+1):
    track = races.iloc[i][2]
    getSession(year,i)
    calculatingDriverLaps(year,i,track)
# Out:
# C:\Users\swavi\AppData\Local\Temp\ipykernel_11480\2021902021.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   track = races.iloc[i][2]
